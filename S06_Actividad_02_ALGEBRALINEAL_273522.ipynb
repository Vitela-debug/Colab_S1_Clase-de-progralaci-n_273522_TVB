# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitela-debug/Colab_S1_Clase-de-progralaci-n_273522_TVB/blob/main/S06_Actividad_02_ALGEBRALINEAL_273522.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad calificada — Álgebra lineal con NumPy
#
# **Programación para Analítica Descriptiva y Predictiva**
# Maestría en Inteligencia Artificial y Analítica de Datos — UACJ
#
# ---
#
# **Material de estudio previo:** `Material_Extra_Algebra_Lineal_NumPy.ipynb`. Revísalo antes de resolver esta actividad.
#
# **Entrega:** individual, en este notebook de Google Colab (comparte el enlace con permiso de edición para el docente).
# **Plazo:** 7 días naturales a partir de la publicación de esta actividad.
# **Penalización por entrega tardía:** 5% por día, hasta 7 días; después de eso, la actividad no se recibe.
# **Valor total:** 100 puntos.
#
# ### Herramientas permitidas
#
# Esta actividad evalúa `np.linalg.norm()`, `np.dot()`/`@`, `np.linalg.det()`, `np.linalg.inv()`, `np.linalg.solve()`, y las operaciones de NumPy ya vistas en sesiones anteriores. No uses pandas ni scikit-learn.
#
# ### Cómo se evalúa
#
# Cada ejercicio indica su valor en puntos. Se evalúa el resultado correcto **y** el uso de la función específica de `np.linalg` indicada en cada enunciado — calcular a mano una fórmula que NumPy ya resuelve (por ejemplo, programar la fórmula del determinante 2×2 en vez de usar `np.linalg.det()`) no obtiene el puntaje completo.
#
# ---
#
#
# **Nombre completo: Tania Vitela Barraza**
# **Matrícula: 273522**
#
# ---

# %%
import numpy as np

# %% [markdown]
# ## Parte 1 — Vectores: perfiles de producto
#
# Una tienda en línea representa cada producto como un vector de 3 componentes: calificación de calidad, calificación de precio, y calificación de servicio (escala 1 a 5, donde 5 es mejor). Ejecuta la siguiente celda para cargar los tres productos — **no la modifiques**.

# %%
producto_A = np.array([4.5, 3.2, 5.0])
producto_B = np.array([4.0, 2.8, 4.7])
producto_C = np.array([1.0, 5.0, 1.2])

print(producto_A, producto_B, producto_C)
# Out:
# [4.5 3.2 5. ] [4.  2.8 4.7] [1.  5.  1.2]

# %% [markdown]
# ---
#
# ### Ejercicio 1 — Norma de los vectores (10 pts)
#
# Calcula la norma de `producto_A`, `producto_B` y `producto_C` usando `np.linalg.norm()`.

# %%
# Tu código aquí
norma_A = np.linalg.norm(producto_A)
norma_B = np.linalg.norm(producto_B)
norma_C = np.linalg.norm(producto_C)
print("Norma_A:",norma_A, "norma_B:",norma_B, "norma_C:",norma_C)
# Out:
# Norma_A: 7.449161026585477 norma_B: 6.777167549942971 norma_C: 5.238320341483518

# %% [markdown]
# ---
# ---
# En el código del ejercicio 1 se calcula la norma de los vectores producto_A, producto_B y producto_C. La norma sirve para saber qué tan grande o qué longitud tiene cada vector ($\|x\| = \sqrt{x_1^2 + x_2^2 + \cdots + x_n^2}$). Para calcularla se utiliza np.linalg.norm(). Finalrmete los resultados se guardan en norma_A, norma_B y norma_C, y se imprimen para poder compararlos.
# ---
# ---

# %% [markdown]
# ---
#
# ### Ejercicio 2 — Producto punto y ángulo (15 pts)
#
# 1. Calcula el producto punto entre `producto_A` y `producto_B`, y entre `producto_A` y `producto_C`, usando `np.dot()` o `@`.
# 2. Calcula el ángulo (en grados) entre `producto_A` y `producto_B`, y entre `producto_A` y `producto_C`.
# 3. Con base en los ángulos obtenidos, indica (en un comentario o celda de texto) cuál de los dos productos (`B` o `C`) es más similar a `producto_A`, y por qué el ángulo es el indicador correcto para esa comparación.

# %%
# Tu código aquí
producto_punto_AB = np.dot(producto_A,producto_B) #producto = producto_A @ producto_B
producto_punto_AC = np.dot(producto_A,producto_C)
print("1. producto_punto_AB:",producto_punto_AB,"producto_punto_AC:",producto_punto_AC)
angulo_AB = np.degrees(np.arccos(producto_punto_AB/(norma_A*norma_B))) #np.degrees() para que sea en grados
angulo_AC = np.degrees((np.arccos(producto_punto_AC/(norma_A*norma_C))))
print("2. angulo_AB:",angulo_AB,"angulo_AC:",angulo_AC)

if angulo_AB < angulo_AC:
    print("3. El producto B es más similar a producto_A porque tiene un ángulo menor.")
else:
    print("3. El producto C es más similar a producto_A porque tiene un ángulo menor.")

print("El ángulo es el indicador correcto porque permite medir la similitud entre los vectores según la dirección que tienen.")
print("Mientras menor sea el ángulo entre dos vectores, más similares son sus direcciones. Además, el cálculo del ángulo normaliza")
print("las magnitudes de los vectores, por lo que la comparación no depende únicamente de qué vector tenga valores más grandes.")
print("En otras palabras: 0° = muy similares, 90° = no tienen similitud direccional, y 180° = direcciones opuestas.")
# Out:
# 1. producto_punto_AB: 50.46 producto_punto_AC: 26.5
# 2. angulo_AB: 1.7745815839558179 angulo_AC: 47.22509268261831
# 3. El producto B es más similar a producto_A porque tiene un ángulo menor.
# El ángulo es el indicador correcto porque permite medir la similitud entre los vectores según la dirección que tienen.
# Mientras menor sea el ángulo entre dos vectores, más similares son sus direcciones. Además, el cálculo del ángulo normaliza
# las magnitudes de los vectores, por lo que la comparación no depende únicamente de qué vector tenga valores más grandes.
# En otras palabras: 0° = muy similares, 90° = no tienen similitud direccional, y 180° = direcciones opuestas.

# %% [markdown]
# ---
# ---
# El código del ejercicio 2 calcula el producto punto entre producto_A y los otros dos productos (B y C) usando np.dot(). Para despues encontrar el ángulo entre los vectores(el ángulo entre A-B y A-C). Para hacerlo, se divide el producto punto entre las normas de los dos vectores y se utiliza arccos() para obtener el ángulo. Finalmente, np.degrees() convierte el resultado de radianes a grados. Posteriormente se comparan los dos ángulos. Si el ángulo entre A y B es menor que el ángulo entre A y C, significa que B es más parecido a A, porque sus direcciones son más cercanas. El ángulo es útil para medir la similitud porque no se enfoca solamente en qué tan grandes son los valores de los vectores, sino en la dirección que tienen. Por eso, mientras menor sea el ángulo, más similares son los vectores: 0° significa que apuntan en la misma dirección, 90° que son perpendiculares y 180° que apuntan en direcciones opuestas.
# ---
# ---

# %% [markdown]
# ---
#
# ### Ejercicio 3 — Normalización (10 pts)
#
# Normaliza los tres vectores (`producto_A`, `producto_B`, `producto_C`) para obtener sus vectores unitarios. Verifica, imprimiendo el resultado, que la norma de cada vector normalizado sea 1.

# %% [markdown]
# ---
# Nota: un vector unitario es un vector con norma igual a 1 — conserva la dirección del vector original, pero no su magnitud. Se obtiene dividiendo el vector entre su propia norma.

# %%
# Tu código aquí
producto_A_unitario = producto_A/norma_A #Se calcula el vector unitario dividiendo el vector ente su norma
producto_B_unitario = producto_B/norma_B #Se calcula el vector unitario dividiendo el vector ente su norma
producto_C_unitario = producto_C/norma_C #Se calcula el vector unitario dividiendo el vector ente su norma

print("Vector unitario A:",producto_A_unitario,"Vector unitario B:",producto_B_unitario,"Vector unitario C:",producto_C_unitario)

#Verificamos con la norma del vector

print("Norma producto_A_unitario:", np.linalg.norm(producto_A_unitario)) #Se calcula la norma del vector unintario de A
print("Norma producto_B_unitario:", np.linalg.norm(producto_B_unitario)) #Se calcula la norma del vector unintario de B
print("Norma producto_C_unitario:", np.linalg.norm(producto_C_unitario)) #Se calcula la norma del vector unintario de C
# Out:
# Vector unitario A: [0.60409488 0.42957858 0.67121653] Vector unitario B: [0.59021707 0.41315195 0.69350506] Vector unitario C: [0.19090089 0.95450444 0.22908106]
# Norma producto_A_unitario: 1.0
# Norma producto_B_unitario: 1.0
# Norma producto_C_unitario: 1.0

# %% [markdown]
# ---
# ---
# El código del ejercicio 3 convierte los vectores producto_A, producto_B y producto_C en vectores unitarios. Se divide cada vector entre su norma ($
# \hat{v} = \frac{\vec{v}}{\|\vec{v}\|}
# $). Esto hace que los vectores conserven la misma dirección, pero que todos tengan una longitud igual a 1.Se utiliza np.linalg.norm() para comprobar que la norma de cada vector unitario sea 1. Si el resultado es 1, significa que la normalización se hizo correctamente.
# ---
# ---

# %% [markdown]
# ## Parte 2 — Matrices: mezcla de insumos
#
# Una fábrica de jugos combina dos insumos (concentrado de fruta y agua) en distintas proporciones para dos líneas de producto. La matriz `M` representa esas proporciones (filas = línea de producto, columnas = insumo), y `P` representa un ajuste de escala para una nueva presentación. Ejecuta la siguiente celda — **no la modifiques**.

# %%
M = np.array([[2, 1],
              [1, 3]])

P = np.array([[1.5, 0],
              [0, 2.0]])

print(M)
print(P)
# Out:
# [[2 1]
#  [1 3]]
# [[1.5 0. ]
#  [0.  2. ]]

# %% [markdown]
# ---
#
# ### Ejercicio 4 — Multiplicación matricial (15 pts)
#
# 1. Calcula `M * P` (elemento a elemento) y `M @ P` (multiplicación matricial). Los resultados son distintos — en un comentario o celda de texto, explica brevemente por qué.
# 2. Verifica que las formas sean compatibles: ¿cuál sería el resultado de `P @ M`? Calcúlalo y compáralo con `M @ P` — ¿da el mismo resultado?

# %%
# Tu código aquí
Elemento_Elemento = M * P #* para la multiplicacion elemento a elemento
Multiplicacion_matricial = M @ P #@ para la multiplicacion matricial
print("1. Elemento_Elemento M*P:",Elemento_Elemento)
print("Multiplicacion_matricial M@P:",Multiplicacion_matricial)

Multiplicacion_matricial2 = P @ M #Se invierte la multiplicacion
print("Verificacion de formas compartibles")
print("2.Multiplicacion_matricial P@M:",Multiplicacion_matricial2)
print("¿Da el mismo resultado?")
print("M * P==M @ P:",M * P==M @ P) #Se compueba si es conmutativo
print("No, # M * P realiza multiplicación elemento a elemento, mientras que M @ P realiza multiplicación matricial, aunque M y P tienen formas compatibles para ambas operaciones. M @ P y P @ M no necesariamente son iguales porque la multiplicación matricial no es conmutativa.")
# Out:
# 1. Elemento_Elemento M*P: [[3. 0.]
#  [0. 6.]]
# Multiplicacion_matricial M@P: [[3.  2. ]
#  [1.5 6. ]]
# Verificacion de formas compartibles
# 2.Multiplicacion_matricial P@M: [[3.  1.5]
#  [2.  6. ]]
# ¿Da el mismo resultado?
# M * P==M @ P: [[ True False]
#  [False  True]]
# No, # M * P realiza multiplicación elemento a elemento, mientras que M @ P realiza multiplicación matricial, aunque M y P tienen formas compatibles para ambas operaciones. M @ P y P @ M no necesariamente son iguales porque la multiplicación matricial no es conmutativa.

# %% [markdown]
# ---
# ---
# Para el ejercio 4 el código compara la multiplicación elemento a elemento con la multiplicación matricial. Primero se utiliza *, que multiplica los valores de M y P que están en la misma posición. Después se utiliza @, que realiza la multiplicación de matrices tomando las filas de una matriz y las columnas de la otra. En la segunda parte se invierte el orden de las matrices haciendo P @ M para comprobar si se obtiene el mismo resultado. Finalmente se compara M * P con M @ P. El resultado es que no son iguales, porque * y @ hacen operaciones diferentes. Además, en la multiplicación matricial el orden de las matrices importa, por lo que M @ P y P @ M no necesariamente dan el mismo resultado.
# ---
# ---

# %% [markdown]
# ---
#
# ### Ejercicio 5 — Determinante e inversa (15 pts)
#
# 1. Calcula el determinante de `M` con `np.linalg.det()`. Confirma que `M` sí tiene inversa (determinante distinto de 0).
# 2. Calcula la inversa de `M` con `np.linalg.inv()`.
# 3. Verifica tu resultado calculando `M @ M_inv` — debe dar (aproximadamente) la matriz identidad.

# %%
# Tu código aquí
determinante_M=np.linalg.det(M) #para calcular el determinante de una matriz
print("1. Determinante de M:", determinante_M)
inversa_M=np.linalg.inv(M) #para calcular la inversa de la matriz M
print("2. Inversa de M:", determinante_M)
Identidad_M=M @ inversa_M #Se calcula la matriz identidad para confirmar la inversa
print("3. Matriz identidad de M @ inversa_M:", Identidad_M)
# Out:
# 1. Determinante de M: 5.000000000000001
# 2. Inversa de M: 5.000000000000001
# 3. Matriz identidad de M @ inversa_M: [[ 1.00000000e+00  0.00000000e+00]
#  [-5.55111512e-17  1.00000000e+00]]

# %% [markdown]
# ---
# ---
# Para el ejercicio 5 el código primero calcula el determinante de la matriz M utilizando np.linalg.det(). Después calcula la matriz inversa de M utilizando np.linalg.inv(). luego semultiplica la matriz M por su inversa usando @. El resultado debería ser una matriz identidad, lo que sirve para comprobar que la inversa de M se calculó correctamente.
# ---
# ---

# %% [markdown]
# ---
#
# ### Ejercicio 6 — Sistema de ecuaciones (15 pts)
#
# La fábrica necesita producir un lote que requiere en total 180 unidades de la línea 1 y 300 unidades de la línea 2, según las proporciones de `M`. Esto se representa como el sistema $Mx = b$, con:
#
# ```python
# b = np.array([180, 300])
# ```
#
# 1. Resuelve el sistema con `np.linalg.solve()` para encontrar cuántas unidades de cada insumo (`x`) se necesitan.
# 2. Verifica tu solución multiplicando `M @ x` y confirmando que el resultado coincide con `b`.

# %%
b = np.array([180, 300])

# Tu código aquí
x=np.linalg.solve(M,b) #para resolver un sistema de ecuaciones
print("1. Unidades  de cada insumo x:", x)
print("2. Confirmacion de solución (M @ x==b):", M @ x==b)
# Out:
# 1. Unidades  de cada insumo x: [48. 84.]
# 2. Confirmacion de solución (M @ x==b): [ True  True]

# %% [markdown]
# ---
# ---
# En el codigo del ejercicio 6 se genera el  vector b (default), que contiene los valores que se buscan obtener como resultado. Después se utiliza np.linalg.solve(M, b) para resolver el sistema de ecuaciones formado por la matriz M y el vector b. El resultado se guarda en x, que representa cuántas unidades de cada insumo se necesitan para cumplir con los valores de b. Para comprobar lso resultados se realiza M @ x y se compara con b para comprobar que la solución sea correcta. Como todos los valores dan True, significa que la solución encontrada para x satisface el sistema de ecuaciones.
# ---
# ---

# %% [markdown]
# ---
#
# ### Ejercicio 7 — Síntesis: distancia y similitud (20 pts)
#
# Retomando los tres productos de la Parte 1:
#
# 1. Calcula la **distancia euclidiana** entre `producto_A` y `producto_B`, y entre `producto_A` y `producto_C`, usando la norma de la diferencia entre los vectores (`np.linalg.norm(a - b)`).
# 2. Calcula la **similitud coseno** entre los mismos pares — es el cociente que ya calculaste en el Ejercicio 2 antes de aplicar `arccos()`: $\frac{a \cdot b}{\|a\| \|b\|}$.
# 3. Con base en ambas métricas (distancia y similitud coseno), concluye en una cadena de texto impresa cuál producto (`B` o `C`) es más parecido a `producto_A`, y si ambas métricas coinciden en la misma conclusión.

# %%
# Tu código aquí
ecluidiana_AB = np.linalg.norm(producto_A - producto_B) #Se calcula la distancia de los dos vectores calculando la norma de ellos
ecluidiana_AC = np.linalg.norm(producto_A - producto_C) #Se calcula la distancia de los dos vectores calculando la norma de ellos
print("1. ecluidiana_AB:",ecluidiana_AB,"ecluidiana_AC:",ecluidiana_AC)

coseno_AB = np.dot(producto_A,producto_B)/(norma_A*norma_B) #Se calcula el producto punto entre los vectores y se divide entre la multiplicacion de sus normas para obtener el coseno de los vectores
coseno_AC = np.dot(producto_A,producto_C)/(norma_A*norma_C) #Se calcula el producto punto entre los vectores y se divide entre la multiplicacion de sus normas para obtener el coseno de los vectores
print("2. coseno_AB:",coseno_AB,"coseno_AC:",coseno_AC)

mas_parecido_distancia = "B" if ecluidiana_AB < ecluidiana_AC else "C" #Se comparan las distancias
mas_parecido_coseno = "B" if coseno_AB > coseno_AC else "C" #Se comparan los cosenos

coinciden = mas_parecido_distancia == mas_parecido_coseno #Se revisa si el mismo vector se parece en distancia y coseno
print("3.") #Se muestan lso resultados finales con solo 4 digitos despues del punto
print(f"Distancia A-B: {ecluidiana_AB:.4f}")
print(f"Distancia A-C: {ecluidiana_AC:.4f}")
print(f"Similitud coseno A-B: {coseno_AB:.4f}")
print(f"Similitud coseno A-C: {coseno_AC:.4f}")

print(
    f"Producto más parecido a A según distancia: {mas_parecido_distancia}. "
    f"Según similitud coseno: {mas_parecido_coseno}. "
    f"Ambas métricas coinciden: {'Sí' if coinciden else 'No'}.") #Se confirma que es similar para ambas metricas
# Out:
# 1. ecluidiana_AB: 0.7071067811865476 ecluidiana_AC: 5.470831746635972
# 2. coseno_AB: 0.9995203969214979 coseno_AC: 0.6791199021706347
# 3.
# Distancia A-B: 0.7071
# Distancia A-C: 5.4708
# Similitud coseno A-B: 0.9995
# Similitud coseno A-C: 0.6791
# Producto más parecido a A según distancia: B. Según similitud coseno: B. Ambas métricas coinciden: Sí.

# %% [markdown]
# ---
# ---
# En el  código del ejercicio 7 se compara que producto (B o C) es más parecido al producto A utilizando dos formas diferentes de medir la similitud. La primera es calculando la distancia euclidiana entre A-B y A-C. Esta distancia indica qué tan separados están los vectores. Por eso, mientras menor sea la distancia, más parecidos son los productos.Luego se calcula la similitud del coseno utilizando el producto punto y las normas de los vectores. Esta medida compara principalmente la dirección de los vectores. Mientras más cercano a 1 sea el coseno, más similares son (el mismo concepto que los grados). Luego se conserva cuál producto es el más parecido según cada método. Para la distancia es el que tenga el valor más pequeño, mientras que para el coseno es el que tiene el valor mas grande. Se comparan los dos resultados para comprobar si ambas métricas consideran que el mismo producto es más parecido a A.
# ---
# ---

# %% [markdown]
# ---
#
# ## Antes de entregar
#
# - Verifica que el notebook completo corra de principio a fin sin errores (**Entorno de ejecución → Ejecutar todas**).
# - Confirma que no usaste pandas ni scikit-learn.
# - Comparte el notebook con permiso de **edición** para el docente.
